# %%
import torch
import torchvision.models.detection as tmd
import torchvision
import matplotlib.pyplot as plt

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
model = tmd.fasterrcnn_resnet50_fpn_v2(weights=torchvision.models.detection.FasterRCNN_ResNet50_FPN_V2_Weights.DEFAULT).cuda()

# %%
from PIL import Image
model.eval()
input_image = Image.open(r"C:\Users\get2b\Desktop\Arav\AI ML\DATA SETS\Neural Network Datasets\Object Detection\VOCdevkit\VOC2007\JPEGImages\000009.jpg")
in_image = torchvision.transforms.ToTensor()(input_image).cuda()
output = model(in_image.unsqueeze(0))

# %%
output[0]['boxes'] = torch.Tensor.detach(output[0]['boxes'])

# %%
output[0]['boxes'] = torch.Tensor.numpy(torch.Tensor.cpu(output[0]['boxes']))

# %%
from matplotlib.patches import Rectangle
import matplotlib
plt.imshow(input_image)
for j in range(0,len(output[0]['boxes'])):
    i = output[0]['boxes']
    x_min = i[j][0]
    x_max = i[j][2]
    y_min = i[j][1]
    y_max = i[j][3]
    w = x_max-x_min
    h = y_max-y_min
    plt.gca().add_patch(Rectangle((x_min,y_min),w,h,
                        edgecolor='red',
                        facecolor='none',
                        lw=2))

# %%
i = output[0]
boxes,labels,scores=[],[],[]
for j in range(0,len(output[0]['boxes'])):
    if i['scores'][j]>0.5:
        boxes.append(i['boxes'][j])
        labels.append(i['labels'][j])
        scores.append(i['scores'][j])

# %%
boxes
# Out:
# [array([ 72.569275, 172.62442 , 263.59567 , 328.6195  ], dtype=float32),
#  array([161.16574, 140.45895, 234.20874, 272.39062], dtype=float32),
#  array([271.01178, 206.46767, 316.17752, 323.10852], dtype=float32),
#  array([260.9931 , 204.93399, 297.06998, 321.91953], dtype=float32),
#  array([475.28354, 226.02939, 491.94373, 235.45802], dtype=float32)]

# %%
plt.imshow(input_image)
for j in range(0,len(boxes)):
    x_min = boxes[j][0]
    x_max = boxes[j][2]
    y_min = boxes[j][1]
    y_max = boxes[j][3]
    w = x_max-x_min
    h = y_max-y_min
    plt.gca().add_patch(Rectangle((x_min,y_min),w,h,
                        edgecolor='red',
                        facecolor='none',
                        lw=2))

# %%
dataset = torchvision.datasets.VOCDetection(root=r'C:\Users\get2b\Desktop\Arav\AI ML\DATA SETS\Neural Network Datasets\Object Detection',year="2007",image_set='val')

# %%
valset_im=[]
valset=[]
for i in range(0,64):
    valset_im.append(torchvision.transforms.ToTensor()(dataset[i][0]).cuda())

# %%
valset_im[0].shape
outputs = model(valset_im[0].unsqueeze(0))

# %%
outputs
# Out:
# [{'boxes': tensor([[4.6713e+00, 2.4417e+02, 6.8316e+01, 3.7500e+02],
#           [1.6498e+02, 2.6476e+02, 2.5171e+02, 3.6914e+02],
#           [4.5650e+02, 1.5028e+02, 4.7358e+02, 1.6785e+02],
#           [2.7817e+02, 1.8545e+02, 3.0768e+02, 2.1691e+02],
#           [2.6321e+02, 2.1064e+02, 3.1824e+02, 3.2803e+02],
#           [2.4488e+02, 1.9304e+02, 2.8251e+02, 2.9285e+02],
#           [4.5162e+02, 1.4008e+02, 4.7765e+02, 1.7429e+02],
#           [3.1210e-01, 1.9767e+02, 3.6273e+01, 3.7161e+02],
#           [4.4458e+02, 1.3289e+02, 4.8544e+02, 1.8647e+02],
#           [1.0189e-01, 1.9829e+02, 3.8847e+01, 2.4882e+02],
#           [3.2545e+02, 1.8979e+02, 3.7744e+02, 2.2254e+02],
#           [2.9712e+02, 2.0329e+02, 3.7437e+02, 3.7026e+02],
#           [9.1232e-02, 2.3492e+01, 1.0492e+01, 5.4065e+01],
#           [2.9533e+02, 2.0915e+02, 3.7453e+02, 3.7285e+02],
#           [2.5257e+02, 3.6132e+02, 2.9328e+02, 3.7500e+02],
#           [2.0736e+02, 3.4752e+02, 3.6966e+02, 3.7476e+02],
#           [3.0608e+02, 1.8994e+02, 3.2628e+02, 2.1232e+02],
#           [3.0639e+02, 1.8810e+02, 3.7392e+02, 2.1931e+02],
#           [4.8402e+02, 1.2302e+02, 4.9351e+02, 1.8044e+02],
#           [3.5298e+02, 2.1045e+02, 4.7633e+02, 3.7491e+02],
#           [3.1727e+02, 1.7467e+02, 3.4522e+02, 1.9187e+02],
#           [3.1682e+02, 1.7519e+02, 3.4481e+02, 2.0780e+02],
#           [2.8725e+02, 1.8824e+02, 3.2926e+02, 2.1401e+02],
#           [3.0657e+02, 1.8903e+02, 3.4246e+02, 2.1532e+02],
#           [4.6323e+02, 1.8551e+02, 4.9885e+02, 3.7320e+02],
#           [2.5453e+02, 1.9422e+02, 3.1362e+02, 2.8046e+02],
#           [2.0202e+02, 1.3466e+02, 2.4653e+02, 2.0844e+02],
#           [4.4027e+02, 2.0063e+02, 4.7830e+02, 2.3264e+02],
#           [2.4663e+02, 2.1241e+02, 3.1907e+02, 3.0639e+02],
#           [1.9080e+02, 3.4348e+02, 4.8872e+02, 3.7473e+02],
#           [2.7640e+02, 1.8919e+02, 3.1384e+02, 2.3090e+02],
#           [6.1903e-02, 1.8775e+02, 3.6832e+01, 3.6954e+02],
#           [4.6597e+02, 1.6685e+02, 4.9960e+02, 3.7408e+02],
#           [2.4118e-01, 2.1520e+02, 3.5484e+01, 3.7319e+02],
#           [8.6247e+01, 2.6785e+02, 1.8880e+02, 3.7450e+02],
#           [2.1048e+02, 3.4687e+02, 3.6551e+02, 3.7500e+02],
#           [3.2474e+02, 1.8831e+02, 3.4602e+02, 2.1542e+02],
#           [3.4911e+02, 3.6765e+02, 4.7040e+02, 3.7500e+02],
#           [2.5243e+02, 3.6123e+02, 2.9288e+02, 3.7495e+02],
#           [2.3183e+02, 2.1456e+02, 3.1763e+02, 2.4997e+02],
#           [3.0796e+02, 2.0917e+02, 4.7767e+02, 3.7388e+02],
#           [3.4752e+02, 3.6062e+02, 4.3198e+02, 3.7500e+02],
#           [4.4103e+02, 2.0188e+02, 4.7877e+02, 2.3110e+02],
#           [4.6684e+02, 2.1100e+02, 4.7334e+02, 2.3100e+02],
#           [3.2797e+02, 1.7602e+02, 3.4213e+02, 1.9154e+02],
#           [4.7267e+02, 1.9446e+02, 4.8981e+02, 2.3340e+02],
#           [2.6995e+02, 2.0833e+02, 3.1886e+02, 2.6122e+02],
#           [1.7122e+02, 1.7360e+02, 1.8546e+02, 1.8977e+02],
#           [3.0928e+02, 2.0155e+02, 3.2527e+02, 2.1604e+02],
#           [1.6272e+02, 2.2159e+02, 1.8096e+02, 2.6874e+02],
#           [4.5912e+02, 1.8879e+02, 4.9986e+02, 3.7500e+02],
#           [3.0907e+02, 2.0171e+02, 3.2537e+02, 2.1602e+02],
#           [2.9627e+02, 2.0684e+02, 3.7841e+02, 3.7101e+02],
#           [1.5707e+02, 1.2966e+02, 1.7399e+02, 1.3594e+02],
#           [3.4391e+02, 2.0961e+02, 4.7555e+02, 3.7500e+02],
#           [2.9427e+02, 1.9844e+02, 3.7769e+02, 3.6876e+02],
#           [2.5519e+02, 3.6114e+02, 2.9299e+02, 3.7500e+02],
#           [2.6533e+02, 2.1109e+02, 3.2078e+02, 2.3469e+02],
#           [3.1552e+02, 1.8368e+02, 3.2561e+02, 1.9217e+02],
#           [1.7184e+02, 1.7393e+02, 1.8645e+02, 1.9002e+02],
#           [0.0000e+00, 1.4458e+02, 3.7337e+01, 2.7660e+02],
#           [2.0401e+02, 1.3525e+02, 2.4595e+02, 1.7359e+02],
#           [1.4338e+02, 2.8073e+02, 1.6306e+02, 2.8469e+02]], device='cuda:0',
#          grad_fn=<StackBackward0>),
#   'labels': tensor([62, 62, 85, 62, 62, 62, 85, 62, 85, 62, 62, 33, 64, 62, 51, 67, 67, 67,
#           84, 82, 64, 64, 67, 67, 65, 62, 62, 62, 67, 67, 62, 63,  1, 67, 67, 62,
#           62, 84, 47, 67, 67, 84, 84, 84, 64, 84, 62, 47, 27, 62, 62, 31, 82, 84,
#           62, 27, 62, 67, 64, 44, 62, 62, 75], device='cuda:0'),
#   'scores': tensor([0.9973, 0.9959, 0.9818, 0.9749, 0.9255, 0.8474, 0.8183, 0.7036, 0.6212,
#           0.5889, 0.5646, 0.4889, 0.3943, 0.3874, 0.3861, 0.3757, 0.3652, 0.3384,
#           0.3292, 0.3171, 0.2870, 0.2318, 0.2125, 0.2093, 0.1968, 0.1938, 0.1893,
#           0.1817, 0.1753, 0.1738, 0.1672, 0.1604, 0.1550, 0.1524, 0.1489, 0.1440,
#           0.1343, 0.1309, 0.1236, 0.1135, 0.1132, 0.0996, 0.0983, 0.0966, 0.0944,
#           0.0932, 0.0901, 0.0873, 0.0799, 0.0766, 0.0736, 0.0729, 0.0703, 0.0702,
#           0.0699, 0.0695, 0.0664, 0.0647, 0.0586, 0.0586, 0.0560, 0.0531, 0.0518],
#          device='cuda:0', grad_fn=<IndexBackward0>)}]

# %%
outputs[0]['boxes'] =(torch.Tensor.detach(outputs[0]['boxes']))

# %%
outputs[0]['boxes'] = torch.Tensor.numpy(torch.Tensor.cpu(outputs[0]['boxes']))

# %%
from matplotlib.patches import Rectangle
import matplotlib
plt.imshow(dataset[0][0])
for j in range(0,len(outputs[0]['boxes'])):
    i = outputs[0]['boxes']
    x_min = i[j][0]
    x_max = i[j][2]
    y_min = i[j][1]
    y_max = i[j][3]
    w = x_max-x_min
    h = y_max-y_min
    plt.gca().add_patch(Rectangle((x_min,y_min),w,h,
                        edgecolor='red',
                        facecolor='none',
                        lw=2))

# %%
i = outputs[0]
boxes,labels,scores=[],[],[]
for j in range(0,len(outputs[0]['boxes'])):
    if i['scores'][j]>0.5:
        boxes.append(i['boxes'][j])
        labels.append(i['labels'][j])
        scores.append(i['scores'][j])

# %%
boxes,labels
# Out:
# ([array([  4.671344, 244.17314 ,  68.31553 , 375.      ], dtype=float32),
#   array([164.98114, 264.7626 , 251.7091 , 369.1401 ], dtype=float32),
#   array([456.49844, 150.28204, 473.5781 , 167.8519 ], dtype=float32),
#   array([278.16946, 185.44614, 307.68475, 216.91042], dtype=float32),
#   array([263.21402, 210.63914, 318.24152, 328.03055], dtype=float32),
#   array([244.87852, 193.04175, 282.50516, 292.84912], dtype=float32),
#   array([451.62213, 140.07579, 477.6486 , 174.28821], dtype=float32),
#   array([3.1209663e-01, 1.9766934e+02, 3.6272598e+01, 3.7160876e+02],
#         dtype=float32),
#   array([444.5829 , 132.88654, 485.4448 , 186.46709], dtype=float32),
#   array([1.0188570e-01, 1.9828551e+02, 3.8846996e+01, 2.4882254e+02],
#         dtype=float32),
#   array([325.45   , 189.7938 , 377.44452, 222.54074], dtype=float32)],
#  [tensor(62, device='cuda:0'),
#   tensor(62, device='cuda:0'),
#   tensor(85, device='cuda:0'),
#   tensor(62, device='cuda:0'),
#   tensor(62, device='cuda:0'),
#   tensor(62, device='cuda:0'),
#   tensor(85, device='cuda:0'),
#   tensor(62, device='cuda:0'),
#   tensor(85, device='cuda:0'),
#   tensor(62, device='cuda:0'),
#   tensor(62, device='cuda:0')])

# %%
plt.imshow(dataset[0][0])
for j in range(0,len(boxes)):
    x_min = boxes[j][0]
    x_max = boxes[j][2]
    y_min = boxes[j][1]
    y_max = boxes[j][3]
    w = x_max-x_min
    h = y_max-y_min
    plt.gca().add_patch(Rectangle((x_min,y_min),w,h,
                        edgecolor='red',
                        facecolor='none',
                        lw=2))

# %%
plt.imshow(dataset[0][0])
